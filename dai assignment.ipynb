# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
set = pd.read_csv('books - Sheet1.csv')

# %%
data['authors'].value_counts().plot(kind="pie",autopct="%1.2f%%")
plt.title('Number of authors')
# Out:
# Text(0.5, 1.0, 'Number of authors')

# %%
data['authors'].value_counts().plot(kind="bar")
plt.title('authors')
# Out:
# Text(0.5, 1.0, 'authors')

# %%
data['publisher'].value_counts().plot(kind="bar")
plt.title('publisher')
# Out:
# Text(0.5, 1.0, 'publisher')

# %%
sns.distplot(data['num_pages'])
plt.title('pages')
# Out:
# C:\Users\lokes\AppData\Local\Temp\ipykernel_17032\4237748550.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['num_pages'])
# Text(0.5, 1.0, 'pages')

# %%
sns.boxplot(data['ratings_count'])
plt.title('ratings count')
# Out:
# Text(0.5, 1.0, 'ratings count')

# %%
sns.scatterplot(data = data,x="num_pages",y="text_reviews_count")
# Out:
# <Axes: xlabel='num_pages', ylabel='text_reviews_count'>

# %%
sns.barplot(data=data,x="num_pages",y="text_reviews_count")
# Out:
# <Axes: xlabel='num_pages', ylabel='text_reviews_count'>

# %%
sns.boxplot(data=data, x="Gende", y="text_reviews_count")
